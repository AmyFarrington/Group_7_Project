# %%
#Uncomment to install missingno if needed
#!pip3 install missingno

# %%
#Imports
import pandas as pd
import missingno as msno

# %%
#Read in csv and create dataframe
NAm_metadata = pd.read_csv('data/NAm_metadata.csv')
#Display 5 rows for reference
NAm_metadata.head(5)
# Out:
#    Unnamed: 0                      strain virus   gisaid_epi_isl  \
# 0          21           DOM/UNIBE001/2021  ncov                ?
# 1          26      CAN/ON-NML-249359/2021  ncov  EPI_ISL_6826713
# 2          43    CAN/SC-COVID22-2779/2022  ncov                ?
# 3          47            DOM/1564087/2021  ncov  EPI_ISL_8642577
# 4          48  DOM/3002833757_760563/2021  ncov  EPI_ISL_6368813
#
#   genbank_accession genbank_accession_rev sra_accession        date  \
# 0          MZ645039            MZ645039.1           NaN  2021-06-10
# 1          OL677199            OL677199.1   SRR17069552  2021-11-23
# 2          ON239776            ON239776.1           NaN  2022-03-17
# 3          OM248500            OM248500.1           NaN  2021-11-29
# 4          ON017707            ON017707.1           NaN  2021-05-21
#
#           region             country  ... QC_frame_shifts QC_stop_codons  \
# 0  North America  Dominican Republic  ...            good           good
# ...

# %%
#Summarize dataframe 
NAm_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3096 entries, 0 to 3095
# Data columns (total 57 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              3096 non-null   int64
#  1   strain                  3096 non-null   object
#  2   virus                   3096 non-null   object
#  3   gisaid_epi_isl          3096 non-null   object
#  4   genbank_accession       3096 non-null   object
#  5   genbank_accession_rev   3096 non-null   object
#  6   sra_accession           2263 non-null   object
#  7   date                    3096 non-null   object
#  8   region                  3096 non-null   object
#  9   country                 3096 non-null   object
#  10  division                3096 non-null   object
#  11  location                208 non-null    object
#  12  region_exposure         3096 non-null   object
#  13  country_exposure        3096 non-null   object
# ...

# %%
#Print number of "NaN" values by column
missing_values = NAm_metadata.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0                   0
# strain                       0
# virus                        0
# gisaid_epi_isl               0
# genbank_accession            0
# genbank_accession_rev        0
# sra_accession              833
# date                         0
# region                       0
# country                      0
# division                     0
# location                  2888
# region_exposure              0
# country_exposure             0
# division_exposure            0
# segment                      0
# length                       0
# host                         0
# age                          0
# sex                          0
# Nextstrain_clade             0
# pango_lineage                1
# GISAID_clade                 0
# originating_lab              0
# submitting_lab              15
# authors                      0
# url                          0
# title                     3096
# paper_url                    0
# date_submitted               0
# ...

# %%
#Create Matrix showing location of "NaN" values
msno.matrix(NAm_metadata, labels='True')
# Out:
# <AxesSubplot:>

# %%
#Print number of "?" values by column
question_marks = (NAm_metadata == '?').sum()

print(question_marks)
# Out:
# Unnamed: 0                   0
# strain                       0
# virus                        0
# gisaid_epi_isl            2474
# genbank_accession            0
# genbank_accession_rev        0
# sra_accession              188
# date                         0
# region                       0
# country                      0
# division                     0
# location                     0
# region_exposure              0
# country_exposure             0
# division_exposure            0
# segment                      0
# length                       0
# host                         0
# age                       1371
# sex                       1203
# Nextstrain_clade             0
# pango_lineage                0
# GISAID_clade              3096
# originating_lab            834
# submitting_lab               0
# authors                      0
# url                          0
# title                        0
# paper_url                 3096
# date_submitted               0
# ...

# %%
#Display bar chart of number of "NaN" per column
msno.bar(NAm_metadata, sort="ascending")
# Out:
# <AxesSubplot:>

# %%
#Replace "?" with "NaN"
NAm_no_qm = NAm_metadata.replace('?', pd.NA)

# %%
#Display matrix of "NaN" values, including values that were previously "?"
msno.matrix(NAm_no_qm, labels='True')
# Out:
# <AxesSubplot:>

# %%
#Display bar chart of number of "NaN" per column, including values that were previously "?"
msno.bar(NAm_no_qm, sort="ascending")
# Out:
# <AxesSubplot:>
